# %% [markdown]
# # 第五次课作业

# %%
import pandas as pd

# %% [markdown]
# （1）读取数据。读取之前作业保存的“酒店数据1.xlsx”

# %%
df = pd.read_excel('酒店数据1.xlsx')

# %% [markdown]
# （2）将“类型”和“名字”设置为层次化索引，并交换索引的位置。然后将层次化索引取消。

# %%
df = df.set_index(['类型','名字'])
df
# Out:
#                                                          城市    地区  \
# 类型   名字
# 浪漫情侣 香港铜锣湾皇悦酒店(Empire Hotel Hong Kong-Causeway Bay)      香港    东区
# 商务出行 香港碧荟酒店(The BEACON)                                  香港   油尖旺
# 浪漫情侣 香港湾仔帝盛酒店(Dorsett Wanchai)                           香港    湾仔
#      如心艾朗酒店(L‘hotel elan)                                香港    观塘
#      香港隆堡柏宁顿酒店(Hotel Pennington by Rhombus)              香港    湾仔
# 海滨风光 海景嘉福洲际酒店(InterContinental Grand Stanford Hong K...  香港   油尖旺
#      香港怡东酒店(Excelsior Hotel)                             香港    湾仔
# 休闲度假 香港富豪九龙酒店(Regal Kowloon Hotel)                       香港   油尖旺
# 海滨风光 港岛香格里拉大酒店(Island Shangri-La)                        香港   中西区
# 地铁周边 香港广易商务宾馆(家庭旅馆)(WIDE EVER HOSTEL)                    香港   油尖旺
# 休闲度假 香港铜锣湾皇冠假日酒店(Crowne Plaza Hong Kong Causeway Bay)    香港    湾仔
# 海滨风光 香港都会海逸酒店(Harbour Plaza Metropolis)                  香港   油尖旺
# 休闲度假 如心南湾海景酒店(L‘hotel Island South)                      香港    南区
# ...

# %%
df.swaplevel('类型','名字')
# Out:
#                                                          城市    地区  \
# 名字                                                 类型
# 香港铜锣湾皇悦酒店(Empire Hotel Hong Kong-Causeway Bay)     浪漫情侣  香港    东区
# 香港碧荟酒店(The BEACON)                                 商务出行  香港   油尖旺
# 香港湾仔帝盛酒店(Dorsett Wanchai)                          浪漫情侣  香港    湾仔
# 如心艾朗酒店(L‘hotel elan)                               浪漫情侣  香港    观塘
# 香港隆堡柏宁顿酒店(Hotel Pennington by Rhombus)             浪漫情侣  香港    湾仔
# 海景嘉福洲际酒店(InterContinental Grand Stanford Hong K... 海滨风光  香港   油尖旺
# 香港怡东酒店(Excelsior Hotel)                            海滨风光  香港    湾仔
# 香港富豪九龙酒店(Regal Kowloon Hotel)                      休闲度假  香港   油尖旺
# 港岛香格里拉大酒店(Island Shangri-La)                       海滨风光  香港   中西区
# 香港广易商务宾馆(家庭旅馆)(WIDE EVER HOSTEL)                   地铁周边  香港   油尖旺
# 香港铜锣湾皇冠假日酒店(Crowne Plaza Hong Kong Causeway Bay)   休闲度假  香港    湾仔
# 香港都会海逸酒店(Harbour Plaza Metropolis)                 海滨风光  香港   油尖旺
# ...

# %%
df = df.reset_index()
df
# Out:
#      index    类型                                                 名字  城市    地区  \
# 0        0  浪漫情侣     香港铜锣湾皇悦酒店(Empire Hotel Hong Kong-Causeway Bay)  香港    东区
# 1        1  商务出行                                 香港碧荟酒店(The BEACON)  香港   油尖旺
# 2        2  浪漫情侣                          香港湾仔帝盛酒店(Dorsett Wanchai)  香港    湾仔
# 3        3  浪漫情侣                               如心艾朗酒店(L‘hotel elan)  香港    观塘
# 4        4  浪漫情侣             香港隆堡柏宁顿酒店(Hotel Pennington by Rhombus)  香港    湾仔
# 5        5  海滨风光  海景嘉福洲际酒店(InterContinental Grand Stanford Hong ...  香港   油尖旺
# 6        6  海滨风光                            香港怡东酒店(Excelsior Hotel)  香港    湾仔
# 7        7  休闲度假                      香港富豪九龙酒店(Regal Kowloon Hotel)  香港   油尖旺
# 8        8  海滨风光                       港岛香格里拉大酒店(Island Shangri-La)  香港   中西区
# 9        9  地铁周边                   香港广易商务宾馆(家庭旅馆)(WIDE EVER HOSTEL)  香港   油尖旺
# 10      10  休闲度假   香港铜锣湾皇冠假日酒店(Crowne Plaza Hong Kong Causeway Bay)  香港    湾仔
# ...

# %% [markdown]
# （3）将数据集转置，获取转制后的index和columns。

# %%
df.T.index
# Out:
# Index(['index', '类型', '名字', '城市', '地区', '地点', '评分', '评分人数', '价格'], dtype='object')

# %%
df.T.columns
# Out:
# RangeIndex(start=0, stop=396, step=1)

# %% [markdown]
# （4）用Groupby方法来计算每个地区的评分人数的总和以及均值。

# %%
df['评分人数'].groupby(df.地区).sum()
# Out:
# 地区
# 东区       56643
# 中西区      59682
# 九龙城      49855
# 元朗        1200
# 其他地区     16831
# 南区       12867
# 屯门        7324
# 沙田       39622
# 油尖旺     422574
# 深水埗区        16
# 湾仔      107344
# 离岛       60359
# 罗湖区         24
# 荃湾      114610
# 葵青       11544
# 观塘       19137
# Name: 评分人数, dtype: int64

# %%
df['评分人数'].groupby(df.地区).mean()
# Out:
# 地区
# 东区       3540.187500
# 中西区      1808.545455
# 九龙城      2374.047619
# 元朗       1200.000000
# 其他地区      300.553571
# 南区       2573.400000
# 屯门       3662.000000
# 沙田       9905.500000
# 油尖旺      2284.183784
# 深水埗区       16.000000
# 湾仔       2618.146341
# 离岛       5487.181818
# 罗湖区        24.000000
# 荃湾      16372.857143
# 葵青       2308.800000
# 观塘       2733.857143
# Name: 评分人数, dtype: float64

# %% [markdown]
# （5）用Grouby方法计算每个类型的平均价格，最高价和最低价。

# %%
df['价格'].groupby(df.类型).mean()[:5]
# Out:
# 类型
# 交通方便     421.0
# 亲子酒店     745.4
# 休闲度假    1151.3
# 其他类型     269.3
# 印象好      297.0
# Name: 价格, dtype: float64

# %%
df['价格'].groupby(df.类型).max()[:5]
# Out:
# 类型
# 交通方便     421
# 亲子酒店    1686
# 休闲度假    4443
# 其他类型     881
# 印象好      297
# Name: 价格, dtype: int64

# %%
df['价格'].groupby(df.类型).min()[:5]
# Out:
# 类型
# 交通方便    421
# 亲子酒店    269
# 休闲度假    358
# 其他类型     67
# 印象好     297
# Name: 价格, dtype: int64

# %% [markdown]
# （6）数据离散化，按照价格将酒店分为3个等级,0-500为C，500-1000为B,大于1000为A，列名设置为“价格等级”。

# %%
df['价格等级'] = pd.cut(df.价格,[0,500,1000,15000],labels=['C','B','A'])
df
# Out:
#      index    类型                                                 名字  城市    地区  \
# 0        0  浪漫情侣     香港铜锣湾皇悦酒店(Empire Hotel Hong Kong-Causeway Bay)  香港    东区
# 1        1  商务出行                                 香港碧荟酒店(The BEACON)  香港   油尖旺
# 2        2  浪漫情侣                          香港湾仔帝盛酒店(Dorsett Wanchai)  香港    湾仔
# 3        3  浪漫情侣                               如心艾朗酒店(L‘hotel elan)  香港    观塘
# 4        4  浪漫情侣             香港隆堡柏宁顿酒店(Hotel Pennington by Rhombus)  香港    湾仔
# 5        5  海滨风光  海景嘉福洲际酒店(InterContinental Grand Stanford Hong ...  香港   油尖旺
# 6        6  海滨风光                            香港怡东酒店(Excelsior Hotel)  香港    湾仔
# 7        7  休闲度假                      香港富豪九龙酒店(Regal Kowloon Hotel)  香港   油尖旺
# 8        8  海滨风光                       港岛香格里拉大酒店(Island Shangri-La)  香港   中西区
# 9        9  地铁周边                   香港广易商务宾馆(家庭旅馆)(WIDE EVER HOSTEL)  香港   油尖旺
# 10      10  休闲度假   香港铜锣湾皇冠假日酒店(Crowne Plaza Hong Kong Causeway Bay)  香港    湾仔
# ...

# %% [markdown]
# （7）获取评分均值最高和最低的地区的数据，分别使用append和concat方法将获取的两个数据集合并。

# %%
df.groupby(df.地区).mean()
# Out:
#            index        评分          评分人数           价格
# 地区
# 东区    132.312500  4.480186   3540.187500   759.937500
# 中西区   138.030303  4.548485   1808.545455  1978.121212
# 九龙城   169.523810  4.428571   2374.047619   640.476190
# 元朗    149.000000  4.500000   1200.000000   425.000000
# 其他地区  276.678571  4.184117    300.553571   276.125000
# 南区    189.000000  4.220000   2573.400000   364.200000
# 屯门     96.000000  4.600000   3662.000000   639.000000
# 沙田    121.500000  4.575000   9905.500000   848.000000
# 油尖旺   212.572973  4.194663   2284.183784   544.362162
# 深水埗区  312.000000  4.300000     16.000000   648.000000
# 湾仔    149.609756  4.375610   2618.146341   829.243902
# 离岛    167.909091  4.371179   5487.181818  1033.363636
# 罗湖区   388.000000  4.282973     24.000000   506.000000
# 荃湾    147.285714  4.442857  16372.857143   480.428571
# 葵青    173.800000  4.040000   2308.800000   342.200000
# 观塘    115.000000  4.500000   2733.857143   661.428571

# %%
df1 = df[df.地区=='屯门']
df2 = df[df.地区=='葵青']

# %%
df11 = df1.append(df2)
df22 = pd.concat([df1,df2])
df22
# Out:
#      index    类型                                        名字  城市  地区  \
# 24      24  海滨风光      香港黄金海岸酒店(Hong Kong Gold Coast Hotel)  香港  屯门
# 168    168  浪漫情侣  香港屯门贝尔特酒店(pentahotel Hong Kong Tuen Mun)  香港  屯门
# 42      42  浪漫情侣            香港荃湾旭逸酒店(Hotel Ease Tsuen Wan)  香港  葵青
# 199    199  其他类型                香港永倫800酒店(WINLAND800HOTEL)  香港  葵青
# 200    200  浪漫情侣               香港青逸酒店(Rambler Oasis Hotel)  香港  葵青
# 213    213  浪漫情侣              香港华逸酒店(Rambler Garden Hotel)  香港  葵青
# 215    215  浪漫情侣     香港文化旅馆-翠雅山房(Hong Kong Heritage Lodge)  香港  葵青
#
#                 地点   评分  评分人数   价格 价格等级
# 24   屯门 黄金海岸青山公路1号  4.7  6326  696    B
# 168      新界屯门震寰路六号  4.5   998  582    B
# 42     葵涌圳边街15-19号  4.4   598  394    C
# 199        新界青衣路一号  3.4  3098  196    C
# 200          青衣路1号  4.0  3091  349    C
# 213       青衣 青衣路1号  4.0  3031  349    C
# 215    香港九龙青山道800号  4.4  1726  423    C

# %% [markdown]
# （8）数据离散化，按照评分人数将酒店平均分为3个等级，三个等级的酒店数量尽量保持一致。评分人数最多的为A，最少的为C。列名设置为“热门等级”。

# %%
import numpy as np

# %%
k = np.array(df.评分人数.values)
k.sort()
len(k)/3
# Out:
# 132.0

# %%
bins = [0,k[131],k[263],k[-1]]
df['热门等级'] = pd.cut(df.评分人数,bins,labels=['C','B','A'])
print(len(df3[df.热门等级=='A']))
print(len(df3[df.热门等级=='B']))
print(len(df3[df.热门等级=='C']))
# Out:
# 132
# 132
# 132

# %%
df['热门等级'] = pd.cut(df.评分人数,[0,235,2060,50000],labels=['C','B','A'])
df3 = df
print(len(df3[df.热门等级=='A']))
print(len(df3[df.热门等级=='B']))
print(len(df3[df.热门等级=='C']))
# Out:
# 132
# 132
# 132

# %% [markdown]
# （9）选出评分人数为A，价格也为A的酒店数据，计算其平均评分。

# %%
df4 = df3[(df3.热门等级=='A')&(df3.价格等级=='A')]
df4['评分'].mean()
# Out:
# 4.659090909090908

# %% [markdown]
# （10）取价格最高的5个酒店的数据，使用stack和unstack方法实现dataframe和Series之间的转换。

# %%
df5 = df3.sort_values(by='价格',ascending=False)[:5]

# %%
df5.stack()
# Out:
# 116  index                                              116
#      类型                                                海滨风光
#      名字                香港四季酒店(Four Seasons Hotel Hong Kong)
#      城市                                                  香港
#      地区                                                 中西区
#      地点                                            中环 金融街8号
#      评分                                                 4.8
#      评分人数                                              3461
#      价格                                               12926
#      价格等级                                                 A
#      热门等级                                                 A
# 115  index                                              115
#      类型                                                休闲度假
#      名字       香港置地文华东方酒店(The Landmark Mandarin Oriental HK)
#      城市                                                  香港
#      地区                                                 中西区
# ...

# %%
df5.stack().unstack()
# Out:
#     index    类型                                             名字  城市   地区  \
# 116   116  海滨风光           香港四季酒店(Four Seasons Hotel Hong Kong)  香港  中西区
# 115   115  休闲度假  香港置地文华东方酒店(The Landmark Mandarin Oriental HK)  香港  中西区
# 88     88  海滨风光                            奕居(The Upper House)  香港  中西区
# 82     82  海滨风光                香港半岛酒店(The Peninsula Hong Kong)  香港  油尖旺
# 18     18  海滨风光          香港文华东方酒店(Mandarin Oriental Hong Kong)  香港  中西区
#
#                   地点   评分  评分人数     价格 价格等级 热门等级
# 116         中环 金融街8号  4.8  3461  12926    A    A
# 115  中环 皇后大道中15号置地广场  4.8  1285   4443    A    B
# 88        金钟道88号太古广场  4.8  1369   4356    A    B
# 82          尖沙咀梳士巴利道  4.8  3693   3862    A    A
# 18          中环干诺道中5号  4.8  2452   3609    A    A

# %% [markdown]
# （11）纵向拆分数据集，分为df1和df2，df1包含名字，类型，城市，地区，df2包含名字，地点，评分，评分人数，价格，价格等级，热门等级。

# %%
df11 = df3[['名字','类型','城市','地区']]
df22 = df3[['名字','地点','评分','评分人数','价格','价格等级','热门等级']]
df22
# Out:
#                                                     名字  \
# 0       香港铜锣湾皇悦酒店(Empire Hotel Hong Kong-Causeway Bay)
# 1                                   香港碧荟酒店(The BEACON)
# 2                            香港湾仔帝盛酒店(Dorsett Wanchai)
# 3                                 如心艾朗酒店(L‘hotel elan)
# 4               香港隆堡柏宁顿酒店(Hotel Pennington by Rhombus)
# 5    海景嘉福洲际酒店(InterContinental Grand Stanford Hong ...
# 6                              香港怡东酒店(Excelsior Hotel)
# 7                        香港富豪九龙酒店(Regal Kowloon Hotel)
# 8                         港岛香格里拉大酒店(Island Shangri-La)
# 9                     香港广易商务宾馆(家庭旅馆)(WIDE EVER HOSTEL)
# 10    香港铜锣湾皇冠假日酒店(Crowne Plaza Hong Kong Causeway Bay)
# 11                  香港都会海逸酒店(Harbour Plaza Metropolis)
# 12                      如心南湾海景酒店(L‘hotel Island South)
# 13                       香港朗廷酒店(The Langham Hong Kong)
# 14                  迪士尼探索家度假酒店(Disney Explorers Lodge)
# 15                            香港港丽酒店(Conrad Hong Kong)
# ...

# %% [markdown]
# （12）将df2按照价格进行排序，重新设置df2的索引。索引值等于价格排名。

# %%
df22 = df22.sort_values(by='价格',ascending=False)
df22
# Out:
#                                                     名字  \
# 116               香港四季酒店(Four Seasons Hotel Hong Kong)
# 115      香港置地文华东方酒店(The Landmark Mandarin Oriental HK)
# 88                                 奕居(The Upper House)
# 82                     香港半岛酒店(The Peninsula Hong Kong)
# 18               香港文华东方酒店(Mandarin Oriental Hong Kong)
# 84               香港丽思卡尔顿酒店(The Ritz-Carlton Hong Kong)
# 70                                香港哲维斯酒店(The Jervois)
# 110               香港太子酒店-马哥孛罗(Prince Hotel Marco Polo)
# 114                                香港君悦酒店(Grand Hyatt)
# 8                         港岛香格里拉大酒店(Island Shangri-La)
# 106              香港JW万豪酒店(JW Marriott Hotel Hong Kong)
# 89        香港美利酒店(The Murray Hong Kong a Niccolo Hotel)
# 78                                 香港普特曼酒店(The Putman)
# 15                            香港港丽酒店(Conrad Hong Kong)
# 178                 香港中环石板街酒店(The Pottinger Hong Kong)
# 86                                  香港W酒店(W Hong Kong)
# ...

# %%
df22.index = (range(1,len(df22)+1))
df22
# Out:
#                                                     名字  \
# 1                 香港四季酒店(Four Seasons Hotel Hong Kong)
# 2        香港置地文华东方酒店(The Landmark Mandarin Oriental HK)
# 3                                  奕居(The Upper House)
# 4                      香港半岛酒店(The Peninsula Hong Kong)
# 5                香港文华东方酒店(Mandarin Oriental Hong Kong)
# 6                香港丽思卡尔顿酒店(The Ritz-Carlton Hong Kong)
# 7                                 香港哲维斯酒店(The Jervois)
# 8                 香港太子酒店-马哥孛罗(Prince Hotel Marco Polo)
# 9                                  香港君悦酒店(Grand Hyatt)
# 10                        港岛香格里拉大酒店(Island Shangri-La)
# 11               香港JW万豪酒店(JW Marriott Hotel Hong Kong)
# 12        香港美利酒店(The Murray Hong Kong a Niccolo Hotel)
# 13                                 香港普特曼酒店(The Putman)
# 14                            香港港丽酒店(Conrad Hong Kong)
# 15                  香港中环石板街酒店(The Pottinger Hong Kong)
# 16                                  香港W酒店(W Hong Kong)
# ...

# %% [markdown]
# （13）使用merge方法将df1和df2合并。

# %%
dfnew= pd.merge(df11,df22,on='名字')
dfnew
# Out:
#                                                     名字    类型  城市    地区  \
# 0       香港铜锣湾皇悦酒店(Empire Hotel Hong Kong-Causeway Bay)  浪漫情侣  香港    东区
# 1                                   香港碧荟酒店(The BEACON)  商务出行  香港   油尖旺
# 2                            香港湾仔帝盛酒店(Dorsett Wanchai)  浪漫情侣  香港    湾仔
# 3                                 如心艾朗酒店(L‘hotel elan)  浪漫情侣  香港    观塘
# 4               香港隆堡柏宁顿酒店(Hotel Pennington by Rhombus)  浪漫情侣  香港    湾仔
# 5    海景嘉福洲际酒店(InterContinental Grand Stanford Hong ...  海滨风光  香港   油尖旺
# 6                              香港怡东酒店(Excelsior Hotel)  海滨风光  香港    湾仔
# 7                        香港富豪九龙酒店(Regal Kowloon Hotel)  休闲度假  香港   油尖旺
# 8                         港岛香格里拉大酒店(Island Shangri-La)  海滨风光  香港   中西区
# 9                     香港广易商务宾馆(家庭旅馆)(WIDE EVER HOSTEL)  地铁周边  香港   油尖旺
# 10    香港铜锣湾皇冠假日酒店(Crowne Plaza Hong Kong Causeway Bay)  休闲度假  香港    湾仔
# 11                  香港都会海逸酒店(Harbour Plaza Metropolis)  海滨风光  香港   油尖旺
# ...

# %% [markdown]
# （14）将合并后的数据集保存数据到“酒店数据2.xlsx”。

# %%
dfnew.to_excel('酒店数据2.xlsx')
